# %%
import pandas as pd
from tabulate import tabulate
from IPython.display import display, HTML

# ✅ Step 1: Skip the first two rows — disclaimer + header preview
df = pd.read_csv("Connections.csv", skiprows=2)

# ✅ Step 2: Strip spaces from column names
df.columns = df.columns.str.strip()

# ✅ Step 3: Create Full Name
df["Full Name"] = df["First Name"].fillna('') + " " + df["Last Name"].fillna('')

# ✅ Step 4: Reorder for display
columns_to_show = ["Full Name", "Position", "Company", "Connected On", "Email Address", "URL"]
df = df[columns_to_show]

# ✅ Step 5: Display preview
print("Column Names:", df.columns.tolist())
print("\n🔍 Preview of Cleaned LinkedIn Connections:\n")
print(tabulate(df.head(10), headers="keys", tablefmt="pretty"))
# Out:
# Column Names: ['Full Name', 'Position', 'Company', 'Connected On', 'Email Address', 'URL']
#
# 🔍 Preview of Cleaned LinkedIn Connections:
#
# +---+--------------------------------+--------------------------------+---------------------------+--------------+---------------+----------------------------------------------------------------------+
# |   |           Full Name            |            Position            |          Company          | Connected On | Email Address |                                 URL                                  |
# +---+--------------------------------+--------------------------------+---------------------------+--------------+---------------+----------------------------------------------------------------------+
# | 0 |          Sangeetha M           |       AWS Data Engineer        |      Elevance Health      | 24 Mar 2025  |      nan      |          https://www.linkedin.com/in/sangeetha-m-6215891a0           |
# | 1 |         Vaibhav  Patil         |   Assistant System Engineer    | Tata Consultancy Services | 24 Mar 2025  |      nan      |         https://www.linkedin.com/in/vaibhav-patil-8b908720b          |
# | 2 |          Yingdan Shi           |        Business Analyst        |          Meituan          | 23 Mar 2025  |      nan      |          https://www.linkedin.com/in/yingdan-shi-591229265           |
# | 3 |       Shubham Srivastava       |      Senior Data Engineer      |          Amazon           | 22 Mar 2025  |      nan      |             https://www.linkedin.com/in/shubham-srivstv              |
# | 4 |          Nazid Shaik           |       Software Engineer        |    Ford Motor Company     | 22 Mar 2025  |      nan      |               https://www.linkedin.com/in/nazid-shaik                |
# | 5 |      Anish Viswanathan VR      | Associate Salesforce Developer |            zeb            | 21 Mar 2025  |      nan      |      https://www.linkedin.com/in/anish-viswanathan-vr-50001a235      |
# | 6 |             Baba M             |         Data Engineer          |    Destin IT Solutions    | 20 Mar 2025  |      nan      |                https://www.linkedin.com/in/babamalik                 |
# | 7 |      Aravind Reddy Yalam       |        Personal Project        |         Freelance         | 20 Mar 2025  |      nan      |        https://www.linkedin.com/in/aravind-reddy-y-306ba415b         |
# | 8 | Vishnu Vardhan Reddy Muthumala |     Web Development Intern     |        Excelerate         | 20 Mar 2025  |      nan      | https://www.linkedin.com/in/vishnu-vardhan-reddy-muthumala-9b237817a |
# | 9 |        Fazululla Shaik         |    Oracle EBS SCM Architect    |   Mason Companies, Inc    | 17 Mar 2025  |      nan      |         https://www.linkedin.com/in/fazululla-shaik-818037b2         |
# +---+--------------------------------+--------------------------------+---------------------------+--------------+---------------+----------------------------------------------------------------------+

# %%
job_categories = {
    "Data Science": [
        "data scientist", "machine learning", "ml engineer", "deep learning", "ai", "artificial intelligence"
    ],
    "Data Analyst": [
        "data analyst", "associate analyst", "reporting analyst", "data insights", "data analytics",
        "analytics", "data manager", "analyst", "data analysis"
    ],
    "Business Intelligence": [
        "business analyst", "bi analyst", "business intelligence", "power bi", "tableau", "looker", "qlik", "microstrategy"
    ],
    "Data Engineer": [
        "data engineer", "etl developer", "etl engineer", "big data", "data pipeline", "data integration"
    ],
    "Web Development": [
        "web developer", "frontend developer", "front end", "backend developer", "back end",
        "full stack developer", "full-stack", "web engineer", "web development intern", "web programming intern",
        "full stack engineer", "sr java full stack engineer"
    ],
    "Software Engineering": [
        "software engineer", "developer", "programmer", "system engineer", "systems engineer",
        "senior system executive", "software development engineer", "software development engineer 2",
        "associate engineer", "sde", "system development engineer"
    ],
    "Cybersecurity": [
        "cyber security", "cybersecurity", "security analyst", "security engineer",
        "infosec", "information security", "application security",
        "penetration tester", "vulnerability engineer", "security consultant", "red team", "blue team",
        "cyberops associate", "vulnerability management co-op"
    ],
    "DevOps / Cloud": [
        "devops", "cloud engineer", "site reliability", "sre", "infrastructure", "aws", "azure", "gcp"
    ],
    "Product / Project": [
        "product manager", "project manager", "product owner", "scrum master", "agile"
    ],
    "Quality Assurance / Testing": [
        "qa", "quality assurance", "test engineer", "testing", "manual tester",
        "automation tester", "qa manager"
    ],
    "Talent / HR": [
        "talent acquisition", "recruiter", "human resources", "hr manager", "hrbp",
        "technical recruiter", "recruitment manager"
    ],
    "Consulting": [
        "consultant", "strategy consultant", "business consultant", "implementation consultant"
    ],
    "Marketing": [
        "marketing", "digital marketing", "content marketing", "growth marketing", "seo specialist"
    ],
    "Student": [
        "student", "graduate", "undergraduate", "bachelor", "msc", "ms", "phd", "fresher", "research assistant"
    ],
    "Other": []
}

# %%
# Step 5: Define function to classify
def classify_position(position):
    if pd.isnull(position):
        return "Other"
    
    position = position.lower()
    for category, keywords in job_categories.items():
        if any(keyword in position for keyword in keywords):
            return category
    return "Other"

# %%
# Step 6: Apply classification
df["Job Category"] = df["Position"].apply(classify_position)

# %%
# Step 7: Reorder columns for display
columns_to_show = ["Full Name", "Position", "Job Category", "Company", "Connected On", "Email Address", "URL"]
subset = df[columns_to_show]

# %%
# Step 8: Display as scrollable table in notebook
display(HTML(
    subset.to_html(classes='output_html', index=False)
    + """
    <style>
        .output_html {
            display: block;
            overflow-x: auto;
            overflow-y: auto;
            max-height: 400px;
            max-width: 100%;
            border: 1px solid #aaa;
            font-family: Arial, sans-serif;
        }
    </style>
    """
))
# Out:
# <table border="1" class="dataframe output_html">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Full Name</th>
#       <th>Position</th>
#       <th>Job Category</th>
#       <th>Company</th>
#       <th>Connected On</th>
#       <th>Email Address</th>
#       <th>URL</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Sangeetha M</td>
#       <td>AWS Data Engineer</td>
#       <td>Data Engineer</td>
#       <td>Elevance Health</td>
#       <td>24 Mar 2025</td>
#       <td>NaN</td>
#       <td>https://www.linkedin.com/in/sangeetha-m-6215891a0</td>
#     </tr>
#     <tr>
#       <td>Vaibhav  Patil</td>
#       <td>Assistant System Engineer</td>
#       <td>Software Engineering</td>
#       <td>Tata Consultancy Services</td>
#       <td>24 Mar 2025</td>
#       <td>NaN</td>
#       <td>https://www.linkedin.com/in/vaibhav-patil-8b908720b</td>
#     </tr>
#     <tr>
#       <td>Yingdan Shi</td>
#       <td>Business Analyst</td>
#       <td>Data Analyst</td>
#       <td>Meituan</td>
#       <td>23 Mar 2025</td>
#       <td>NaN</td>
#       <td>https://www.linkedin.com/in/yingdan-shi-591229265</td>
#     </tr>
#     <tr>
#       <td>Shubham Srivastava</td>
#       <td>Senior Data Engineer</td>
#       <td>Data Engineer</td>
#       <td>Amazon</td>
#       <td>22 Mar 2025</td>
#       <td>NaN</td>
#       <td>https://www.linkedin.com/in/shubham-srivstv</td>
#     </tr>
#     <tr>
#       <td>Nazid Shaik</td>
#       <td>Software Engineer</td>
#       <td>Software Engineering</td>
#       <td>Ford Motor Company</td>
#       <td>22 Mar 2025</td>
#       <td>NaN</td>
#       <td>https://www.linkedin.com/in/nazid-shaik</td>
#     </tr>
#     <tr>
#       <td>Anish Viswanathan VR</td>
#       <td>Associate Salesforce Developer</td>
#       <td>Software Engineering</td>
#       <td>zeb</td>
#       <td>21 Mar 2025</td>
#       <td>NaN</td>
#       <td>https://www.linkedin.com/in/anish-viswanathan-vr-50001a235</td>
#     </tr>
#     <tr>
#       <td>Baba M</td>
#       <td>Data Engineer</td>
#       <td>Data Engineer</td>
#       <td>Destin IT Solutions</td>
#       <td>20 Mar 2025</td>
#       <td>NaN</td>
#       <td>https://www.linkedin.com/in/babamalik</td>
#     </tr>
#     <tr>
#       <td>Aravind Reddy Yalam</td>
#       <td>Personal Project</td>
#       <td>Other</td>
#       <td>Freelance</td>
#       <td>20 Mar 2025</td>
#       <td>NaN</td>
#       <td>https://www.linkedin.com/in/aravind-reddy-y-306ba415b</td>
#     </tr>
#     <tr>
#       <td>Vishnu Vardhan Reddy Muthumala</td>
#       <td>Web Development Intern</td>
#       <td>Web Development</td>
#       <td>Excelerate</td>
#       <td>20 Mar 2025</td>
#       <td>NaN</td>
#       <td>https://www.linkedin.com/in/vishnu-vardhan-reddy-muthumala-9b237817a</td>
#     </tr>
#     <tr>
#       <td>Fazululla Shaik</td>
#       <td>Oracle EBS SCM Architect</td>
#       <td>Other</td>
#       <td>Mason Companies, Inc</td>
#       <td>17 Mar 2025</td>
#       <td>NaN</td>
#       <td>https://www.linkedin.com/in/fazululla-shaik-818037b2</td>
#     </tr>
#     <tr>
#       <td>P Naveen</td>
#       <td>Software Engineer</td>
#       <td>Software Engineering</td>
#       <td>Cognizant</td>
#       <td>16 Mar 2025</td>
#       <td>NaN</td>
#       <td>https://www.linkedin.com/in/naveen-pothireddy</td>
#     </tr>
#     <tr>
#       <td>Praveen Mannam</td>
#       <td>System Engineer</td>
#       <td>Software Engineering</td>
#       <td>Imvences</td>
#       <td>16 Mar 2025</td>
#       <td>NaN</td>
#       <td>https://www.linkedin.com/in/praveen-mannam-b71676355</td>
#     </tr>
#     <tr>
#       <td>Nithin chakri B</td>
#       <td>Data Analyst</td>
#       <td>Data Analyst</td>
#       <td>UHS</td>
#       <td>16 Mar 2025</td>
#       <td>NaN</td>
#       <td>https://www.linkedin.com/in/nithin-chakri-b-05623516b</td>
#     </tr>
#     <tr>
#       <td>SAI CHARAN SINGUPURAPU</td>
#       <td>Intern</td>
#       <td>Other</td>
#       <td>National Institute of Advanced Studies</td>
#       <td>14 Mar 2025</td>
#       <td>NaN</td>
#       <td>https://www.linkedin.com/in/sai-charan-singupurapu-527246259</td>
#     </tr>
#     <tr>
#       <td>Vijay Krishna Kesanapalli</td>
#       <td>Software Engineer</td>
#       <td>Software Engineering</td>
#       <td>Cognizant</td>
#       <td>11 Mar 2025</td>
#       <td>NaN</td>
#       <td>https://www.linkedin.com/in/vijayk924</td>
#     </tr>
#     <tr>
#       <td>Raj Dedhia</td>
#       <td>AI Web3 Intern</td>
#       <td>Data Science</td>
#       <td>3ns.domains | Claim Your .Web3 Domain</td>
#       <td>10 Mar 2025</td>
#       <td>NaN</td>
#       <td>https://www.linkedin.com/in/rdedhia1</td>
#     </tr>
#     <tr>
#       <td>Sai Akshay Reddy Mavuram</td>
#       <td>Project Trainee</td>
#       <td>Data Science</td>
#       <td>Wipro</td>
#       <td>09 Mar 2025</td>
#       <td>NaN</td>
#       <td>https://www.linkedin.com/in/sai-akshay-reddy-m-8892761a2</td>
#     </tr>
#     <tr>
#       <td>Ujwal Chikkamavathur Siddlingaiah</td>
#       <td>Manufacturing Engineer</td>
#       <td>Other</td>
#       <td>DaVita Kidney Care</td>
#       <td>05 Mar 2025</td>
#       <td>NaN</td>
#       <td>https://www.linkedin.com/in/ujwalcs</td>
#     </tr>
#     <tr>
#       <td>Boinapally Bhanu Prasad Rao</td>
#       <td>Associate Analyst</td>
#       <td>Data Analyst</td>
#       <td>ASTROC AS TECHNOLOGY PRIVATE LIMITED</td>
#       <td>04 Mar 2025</td>
#       <td>NaN</td>
#       <td>https://www.linkedin.com/in/boinapally-bhanu-prasad-rao-962085225</td>
#     </tr>
#     <tr>
#       <td>Sripooja Kondaparthy</td>
#       <td>NaN</td>
#       <td>Other</td>
#       <td>NaN</td>
#       <td>04 Mar 2025</td>
#       <td>NaN</td>
#       <td>https://www.linkedin.com/in/sripooja</td>
#     </tr>
#     <tr>
#       <td>Pavan Kumar Reddy Yanamala</td>
#       <td>AWS Administrator</td>
#       <td>DevOps / Cloud</td>
#       <td>Mindtree</td>
#       <td>04 Mar 2025</td>
#       <td>NaN</td>
#       <td>https://www.linkedin.com/in/pavan-kumar-reddy-yanamala-4ab599337</td>
#     </tr>
#     <tr>
#       <td>Rohan Bhande</td>
#       <td>Data Analyst Associate Intern</td>
#       <td>Data Analyst</td>
#       <td>Excelerate</td>
#       <td>04 Mar 2025</td>
#       <td>NaN</td>
#       <td>https://www.linkedin.com/in/rohan-bhande-08091a169</td>
#     </tr>
#     <tr>
#       <td>kalyan padasanaboina</td>
#       <td>Senior Data Engineer</td>
#       <td>Data Engineer</td>
#       <td>Broadridge</td>
#       <td>03 Mar 2025</td>
#       <td>NaN</td>
#       <td>https://www.linkedin.com/in/kalyan-padasanaboina-421a88345</td>
#     </tr>
#     <tr>
#       <td>Vurukonda Tharun</td>
#       <td>Senior Software Engineer</td>
#       <td>Software Engineering</td>
#       <td>Capgemini</td>
#       <td>02 Mar 2025</td>
#       <td>NaN</td>
#       <td>https://www.linkedin.com/in/vurukonda-tharun-818b18230</td>
#     </tr>
#     <tr>
#       <td>Jaitra Narasimha Valluri</td>
#       <td>Full Stack Engineer</td>
#       <td>Web Development</td>
#       <td>Li-Mat Soft Solutions Pvt Ltd</td>
#       <td>02 Mar 2025</td>
#       <td>NaN</td>
#       <td>https://www.linkedin.com/in/jaitra-narasimha-valluri</td>
#     </tr>
#     <tr>
#       <td>srinivasareddy daka</td>
#       <td>Data Science Intern</td>
#       <td>Other</td>
#       <td>Personifwy</td>
#       <td>25 Feb 2025</td>
#       <td>NaN</td>
#       <td>https://www.linkedin.com/in/srinivasareddy-daka</td>
#     </tr>
#     <tr>
#       <td>Sharikh  Mohammed</td>
#       <td>Salesforce Developer</td>
#       <td>Software Engineering</td>
#       <td>Career Soft Solutions Inc</td>
#       <td>25 Feb 2025</td>
#       <td>NaN</td>
#       <td>https://www.linkedin.com/in/sharikh-mohammed</td>
#     </tr>
#     <tr>
#       <td>Potti Naga Sai Kumar</td>
#       <td>Programming Analyst</td>
#       <td>Data Analyst</td>
#       <td>Cognizant</td>
#       <td>25 Feb 2025</td>
#       <td>NaN</td>
#       <td>https://www.linkedin.com/in/potti-naga-sai-kumar-63b956156</td>
#     </tr>
#     <tr>
#       <td>Syed Moizuddin</td>
#       <td>Senior Software Engineer</td>
#       <td>Software Engineering</td>
#       <td>Capgemini</td>
#       <td>22 Feb 2025</td>
#       <td>NaN</td>
#       <td>https://www.linkedin.com/in/moizuddin-syed</td>
#     </tr>
#     <tr>
#       <td>Sneha Elizabeth Saji</td>
#       <td>Full Stack Engineer</td>
#       <td>Web Development</td>
#       <td>Model Earth</td>
#       <td>19 Feb 2025</td>
#       <td>NaN</td>
#       <td

# %%
# Save the updated DataFrame to a new CSV file
df.to_csv("linkedin_connections_categorized.csv", index=False)

# %%
# Save only the selected subset of columns
subset.to_csv("linkedin_connections_subset_categorized.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 # Save only the selected subset of columns
#       2 subset.to_csv("linkedin_connections_subset_categorized.csv", index=False)
# ----> 3 df_subset.head(10)
#
# NameError: name 'df_subset' is not defined
